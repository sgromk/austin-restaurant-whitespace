# %% [markdown]
# # Austin Restaurant Data Analysis
# An investigation into the relationship between visual content (restaurant photos) and customer ratings using Google Places and Cloud Vision APIs.

# %% [markdown]
# # Unstructured Data Analytics Final Project
#
# ### Gabriel Kinshuk, Carol Le, Vyshnavi Maringanti, Niladri Nath, Radha Pawar

# %% [markdown]
# #### Using the Google Places API to get data about restaurants in Austin

# %% [markdown]
# Dependencies

# %%
# !pip install requests pandas

# %% [markdown]
# Imports

# %%
import requests
import json
import time
import pandas as pd
import math
from typing import List, Dict, Any, Tuple

# %% [markdown]
# Configuration

# %%
with open("google_places_api_key.txt", "r") as f:
    API_KEY = f.read().strip()

# %% [markdown]
# Scraper Class - We initially intended to scrape the data directly but found we could instead use the Google Places API, so this name is slightly misleading

# %%
class AustinRestaurantScraper:
    def __init__(self, api_key: str):
        self.api_key = api_key
        self.base_url = "https://maps.googleapis.com/maps/api/place"
        
    def generate_grid_points(self, bounds: Dict[str, float], radius_km: float = 1.5) -> List[Tuple[float, float]]:
        """
        Generate a grid of lat/lng points to cover Austin comprehensively.
        
        Args:
            bounds: Dict with 'north', 'south', 'east', 'west' coordinates
            radius_km: Search radius in kilometers (smaller = more coverage, more API calls)
        
        Returns:
            List of (lat, lng) tuples
        """
        # Convert radius to approximate degrees
        # 1 degree latitude ≈ 111 km
        # 1 degree longitude ≈ 111 km * cos(latitude) - at Austin's latitude ~96 km
        lat_step = (radius_km * 1.4) / 111  # 1.4x radius for overlap
        lng_step = (radius_km * 1.4) / 96
        
        points = []
        lat = bounds['south']
        
        while lat <= bounds['north']:
            lng = bounds['west']
            while lng <= bounds['east']:
                points.append((lat, lng))
                lng += lng_step
            lat += lat_step
        
        print(f"Generated {len(points)} grid points with {radius_km}km radius")
        return points
    
    def nearby_search(self, lat: float, lng: float, radius: int = 1500) -> List[str]:
        """
        Search for restaurants near a specific location.
        
        Args:
            lat: Latitude
            lng: Longitude
            radius: Search radius in meters (max 50000)
        
        Returns:
            List of place_ids
        """
        place_ids = []
        url = f"{self.base_url}/nearbysearch/json"
        
        params = {
            "location": f"{lat},{lng}",
            "radius": radius,
            "type": "restaurant",
            "key": self.api_key
        }
        
        while True:
            response = requests.get(url, params=params)
            data = response.json()
            
            if data.get("status") not in ["OK", "ZERO_RESULTS"]:
                print(f"Search error at ({lat}, {lng}): {data.get('status')}")
                break
            
            # Collect place_ids
            for result in data.get("results", []):
                place_ids.append(result["place_id"])
            
            # Check for next page
            next_page_token = data.get("next_page_token")
            if not next_page_token:
                break
            
            # Wait before requesting next page (required by API)
            time.sleep(2)
            params = {"pagetoken": next_page_token, "key": self.api_key}
        
        return place_ids
    
    def search_all_grid_points(self, bounds: Dict[str, float], radius_km: float = 1.5) -> List[str]:
        """
        Search all grid points and return unique place_ids.
        """
        grid_points = self.generate_grid_points(bounds, radius_km)
        all_place_ids = set()
        
        for i, (lat, lng) in enumerate(grid_points, 1):
            print(f"Searching grid point {i}/{len(grid_points)}: ({lat:.4f}, {lng:.4f})")
            
            place_ids = self.nearby_search(lat, lng, radius=int(radius_km * 1000))
            new_ids = len(place_ids) - len(all_place_ids & set(place_ids))
            all_place_ids.update(place_ids)
            
            print(f"  Found {len(place_ids)} restaurants ({new_ids} new) - Total unique: {len(all_place_ids)}")
            
            # Rate limiting between grid points
            time.sleep(0.5)
        
        print(f"\n✓ Total unique restaurants found: {len(all_place_ids)}")
        return list(all_place_ids)
    
    def get_place_details(self, place_id: str) -> Dict[str, Any]:
        """
        Get detailed information for a specific place.
        """
        url = f"{self.base_url}/details/json"
        
        fields = [
            "place_id",
            "name",
            "formatted_address",
            "address_components",
            "geometry",
            "vicinity",
            "types",
            "business_status",
            "rating",
            "user_ratings_total",
            "price_level",
            "opening_hours",
            "website",
            "url",
            "reviews",
            "photos",
            "serves_beer",
            "serves_wine",
            "dine_in",
            "takeout",
            "curbside_pickup",
            "delivery",
            "reservable",
            "editorial_summary"
        ]
        
        params = {
            "place_id": place_id,
            "fields": ",".join(fields),
            "key": self.api_key
        }
        
        response = requests.get(url, params=params)
        data = response.json()
        
        if data.get("status") == "OK":
            return data.get("result", {})
        else:
            return {}
    
    def flatten_restaurant_data(self, details: Dict[str, Any]) -> Dict[str, Any]:
        """
        Flatten the nested API response into a single-level dictionary.
        """
        flattened = {
            "place_id": details.get("place_id"),
            "name": details.get("name"),
            "formatted_address": details.get("formatted_address"),
            "address_components": json.dumps(details.get("address_components", [])),
            "lat": details.get("geometry", {}).get("location", {}).get("lat"),
            "lng": details.get("geometry", {}).get("location", {}).get("lng"),
            "vicinity": details.get("vicinity"),
            "types": json.dumps(details.get("types", [])),
            "business_status": details.get("business_status"),
            "rating": details.get("rating"),
            "user_ratings_total": details.get("user_ratings_total"),
            "price_level": details.get("price_level"),
            "opening_hours_weekday_text": json.dumps(details.get("opening_hours", {}).get("weekday_text", [])),
            "opening_hours_periods": json.dumps(details.get("opening_hours", {}).get("periods", [])),
            "website": details.get("website"),
            "url": details.get("url"),
            "serves_beer": details.get("serves_beer"),
            "serves_wine": details.get("serves_wine"),
            "dine_in": details.get("dine_in"),
            "takeout": details.get("takeout"),
            "curbside_pickup": details.get("curbside_pickup"),
            "delivery": details.get("delivery"),
            "reservable": details.get("reservable"),
            "editorial_summary": details.get("editorial_summary", {}).get("overview"),
        }
        
        # Handle reviews
        reviews = details.get("reviews", [])
        flattened["reviews"] = json.dumps([{
            "rating": r.get("rating"),
            "text": r.get("text"),
            "author_name": r.get("author_name"),
            "time": r.get("time"),
            "relative_time_description": r.get("relative_time_description")
        } for r in reviews])
        
        # Handle photos
        photos = details.get("photos", [])
        flattened["photos"] = json.dumps([{
            "photo_reference": p.get("photo_reference"),
            "height": p.get("height"),
            "width": p.get("width")
        } for p in photos])
        
        return flattened

# %% [markdown]
# Initialize scraper

# %%
scraper = AustinRestaurantScraper(API_KEY)

# %% [markdown]
# Define Austin bounds and search with dense grid

# %%
# Austin metropolitan area bounding box
austin_bounds = {
    "north": 30.5168,   # North Austin/Round Rock
    "south": 30.0986,   # South Austin/Buda
    "east": -97.5684,   # East Austin
    "west": -97.9383    # West Austin/Lake Travis
}

print("=" * 60)
print("GRID-BASED RESTAURANT SEARCH")
print("=" * 60)
print(f"Search area: {austin_bounds}")
print(f"Target: ~2000 restaurants")
print("=" * 60)

# Use 1.5km radius for dense coverage
# This will create ~40-50 grid points for comprehensive coverage
place_ids = scraper.search_all_grid_points(austin_bounds, radius_km=1.5)

print(f"\n{'='*60}")
print(f"SEARCH COMPLETE: {len(place_ids)} unique restaurants found")
print(f"{'='*60}")
# Out:
# ============================================================
# GRID-BASED RESTAURANT SEARCH
# ============================================================
# Search area: {'north': 30.5168, 'south': 30.0986, 'east': -97.5684, 'west': -97.9383}
# Target: ~2000 restaurants
# ============================================================
# Generated 391 grid points with 1.5km radius
# Searching grid point 1/391: (30.0986, -97.9383)
#   Found 0 restaurants (0 new) - Total unique: 0
# Searching grid point 2/391: (30.0986, -97.9164)
#   Found 0 restaurants (0 new) - Total unique: 0
# Searching grid point 3/391: (30.0986, -97.8946)
#   Found 0 restaurants (0 new) - Total unique: 0
# Searching grid point 4/391: (30.0986, -97.8727)
#   Found 10 restaurants (10 new) - Total unique: 10
# Searching grid point 5/391: (30.0986, -97.8508)
#   Found 0 restaurants (0 new) - Total unique: 10
# Searching grid point 6/391: (30.0986, -97.8289)
#   Found 22 restaurants (22 new) - Total unique: 32
# Searching grid point 7/391: (30.0986, -97.8071)
#   Found 9 restaurants (5 new) - Total unique: 37
# Searching grid point 8/391: (30.0986, -97.7852)
#   Found 0 restaurants (0 new) - Total unique: 37
# Searching grid point 9/391: (30.0986, -97.7633)
#   Found 1 restaurants (1 new) - Total unique: 38
# Searching grid point 10/391: (30.0986, -97.7414)
#   Found 5 restaurants (4 new) - Total unique: 42
# Searching grid point 11/391: (30.0986, -97.7196)
#   Found 0 restaurants (0 new) - Total unique: 42
# Searching grid point 12/391: (30.0986, -97.6977)
#   Found 6 restaurants (6 new) - Total unique: 48
# Searching grid point 13/391: (30.0986, -97.6758)
#   Found 0 restaurants (0 new) - Total unique: 48
# Searching grid point 14/391: (30.0986, -97.6539)
#   Found 0 restaurants (0 new) - Total unique: 48
# Searching grid point 15/391: (30.0986, -97.6321)
#   Found 0 restaurants (0 new) - Total unique: 48
# Searching grid point 16/391: (30.0986, -97.6102)
#   Found 12 restaurants (12 new) - Total unique: 60
# Searching grid point 17/391: (30.0986, -97.5883)
#   Found 6 restaurants (2 new) - Total unique: 62
# Searching grid point 18/391: (30.1175, -97.9383)
#   Found 0 restaurants (0 new) - Total unique: 62
# Searching grid point 19/391: (30.1175, -97.9164)
#   Found 0 restaurants (0 new) - Total unique: 62
# Searching grid point 20/391: (30.1175, -97.8946)
#   Found 0 restaurants (0 new) - Total unique: 62
# Searching grid point 21/391: (30.1175, -97.8727)
#   Found 2 restaurants (2 new) - Total unique: 64
# Searching grid point 22/391: (30.1175, -97.8508)
#   Found 1 restaurants (1 new) - Total unique: 65
# Searching grid point 23/391: (30.1175, -97.8289)
#   Found 0 restaurants (0 new) - Total unique: 65
# Searching grid point 24/391: (30.1175, -97.8071)
#   Found 0 restaurants (0 new) - Total unique: 65
# Searching grid point 25/391: (30.1175, -97.7852)
#   Found 0 restaurants (0 new) - Total unique: 65
# Searching grid point 26/391: (30.1175, -97.7633)
#   Found 0 restaurants (0 new) - Total unique: 65
# Searching grid point 27/391: (30.1175, -97.7414)
#   Found 0 restaurants (0 new) - Total unique: 65
# Searching grid point 28/391: (30.1175, -97.7196)
#   Found 0 restaurants (0 new) - Total unique: 65
# Searching grid point 29/391: (30.1175, -97.6977)
#   Found 8 restaurants (7 new) - Total unique: 72
# Searching grid point 30/391: (30.1175, -97.6758)
#   Found 0 restaurants (0 new) - Total unique: 72
# Searching grid point 31/391: (30.1175, -97.6539)
#   Found 0 restaurants (0 new) - Total unique: 72
# Searching grid point 32/391: (30.1175, -97.6321)
#   Found 5 restaurants (5 new) - Total unique: 77
# Searching grid point 33/391: (30.1175, -97.6102)
#   Found 0 restaurants (0 new) - Total unique: 77
# Searching grid point 34/391: (30.1175, -97.5883)
#   Found 4 restaurants (2 new) - Total unique: 79
# Searching grid point 35/391: (30.1364, -97.9383)
#   Found 0 restaurants (0 new) - Total unique: 79
# Searching grid point 36/391: (30.1364, -97.9164)
#   Found 0 restaurants (0 new) - Total unique: 79
# Searching grid point 37/391: (30.1364, -97.8946)
#   Found 0 restaurants (0 new) - Total unique: 79
# Searching grid point 38/391: (30.1364, -97.8727)
#   Found 0 restaurants (0 new) - Total unique: 79
# Searching grid point 39/391: (30.1364, -97.8508)
#   Found 4 restaurants (3 new) - Total unique: 82
# Searching grid point 40/391: (30.1364, -97.8289)
#   Found 13 restaurants (13 new) - Total unique: 95
# Searching grid point 41/391: (30.1364, -97.8071)
#   Found 9 restaurants (9 new) - Total unique: 104
# Searching grid point 42/391: (30.1364, -97.7852)
#   Found 5 restaurants (1 new) - Total unique: 105
# Searching grid point 43/391: (30.1364, -97.7633)
#   Found 1 restaurants (1 new) - Total unique: 106
# Searching grid point 44/391: (30.1364, -97.7414)
#   Found 1 restaurants (1 new) - Total unique: 107
# Searching grid point 45/391: (30.1364, -97.7196)
#   Found 0 restaurants (0 new) - Total unique: 107
# Searching grid point 46/391: (30.1364, -97.6977)
#   Found 0 restaurants (0 new) - Total unique: 107
# Searching grid point 47/391: (30.1364, -97.6758)
#   Found 5 restaurants (5 new) - Total unique: 112
# Searching grid point 48/391: (30.1364, -97.6539)
#   Found 5 restaurants (2 new) - Total unique: 114
# Searching grid point 49/391: (30.1364, -97.6321)
#   Found 3 restaurants (1 new) - Total unique: 115
# Searching grid point 50/391: (30.1364, -97.6102)
#   Found 2 restaurants (1 new) - Total unique: 116
# Searching grid point 51/391: (30.1364, -97.5883)
#   Found 0 restaurants (0 new) - Total unique: 116
# Searching grid point 52/391: (30.1554, -97.9383)
#   Found 0 restaurants (0 new) - Total unique: 116
# Searching grid point 53/391: (30.1554, -97.9164)
#   Found 0 restaurants (0 new) - Total unique: 116
# Searching grid point 54/391: (30.1554, -97.8946)
#   Found 0 restaurants (0 new) - Total unique: 116
# Searching grid point 55/391: (30.1554, -97.8727)
#   Found 0 restaurants (0 new) - Total unique: 116
# Searching grid point 56/391: (30.1554, -97.8508)
#   Found 0 restaurants (0 new) - Total unique: 116
# Searching grid point 57/391: (30.1554, -97.8289)
#   Found 30 restaurants (23 new) - Total unique: 139
# Searching grid point 58/391: (30.1554, -97.8071)
#   Found 10 restaurants (10 new) - Total unique: 149
# Searching grid point 59/391: (30.1554, -97.7852)
#   Found 60 restaurants (50 new) - Total unique: 199
# Searching grid point 60/391: (30.1554, -97.7633)
#   Found 18 restaurants (10 new) - Total unique: 209
# Searching grid point 61/391: (30.1554, -97.7414)
#   Found 3 restaurants (3 new) - Total unique: 212
# Searching grid point 62/391: (30.1554, -97.7196)
#   Found 11 restaurants (11 new) - Total unique: 223
# Searching grid point 63/391: (30.1554, -97.6977)
#   Found 31 restaurants (31 new) - Total unique: 254
# Searching grid point 64/391: (30.1554, -97.6758)
#   Found 9 restaurants (2 new) - Total unique: 256
# Searching grid point 65/391: (30.1554, -97.6539)
#   Found 1 restaurants (1 new) - Total unique: 257
# Searching grid point 66/391: (30.1554, -97.6321)
#   Found 1 restaurants (0 new) - Total unique: 257
# Searching grid point 67/391: (30.1554, -97.6102)
#   Found 0 restaurants (0 new) - Total unique: 257
# Searching grid point 68/391: (30.1554, -97.5883)
#   Found 2 restaurants (2 new) - Total unique: 259
# Searching grid point 69/391: (30.1743, -97.9383)
#   Found 0 restaurants (0 new) - Total unique: 259
# Searching grid point 70/391: (30.1743, -97.9164)
#   Found 1 restaurants (1 new) - Total unique: 260
# Searching grid point 71/391: (30.1743, -97.8946)
#   Found 0 restaurants (0 new) - Total unique: 260
# Searching grid point 72/391: (30.1743, -97.8727)
#   Found 0 restaurants (0 new) - Total unique: 260
# Searching grid point 73/391: (30.1743, -97.8508)
#   Found 16 restaurants (16 new) - Total unique: 276
# Searching grid point 74/391: (30.1743, -97.8289)
#   Found 55 restaurants (36 new) - Total unique: 312
# Searching grid point 75/391: (30.1743, -97.8071)
#   Found 15 restaurants (13 new) - Total unique: 325
# Searching grid point 76/391: (30.1743, -97.7852)
#   Found 60 restaurants (33 new) - Total unique: 358
# Searching grid point 77/391: (30.1743, -97.7633)
#   Found 12 restaurants (9 new) - Total unique: 367
# Searching grid point 78/391: (30.1743, -97.7414)
#   Found 6 restaurants (6 new) - Total unique: 373
# Searching grid point 79/391: (30.1743, -97.7196)
#   Found 1 restaurants (0 new) - Total unique: 373
# Searching grid point 80/391: (30.1743, -97.6977)
#   Found 32 restaurants (12 new) - Total unique: 385
# Searching grid point 81/391: (30.1743, -97.6758)
#   Found 6 restaurants (0 new) - Total unique: 385
# Searching grid point 82/391: (30.1743, -97.6539)
#   Found 1 restaurants (1 new) - Total unique: 386
# Searching grid point 83/391: (30.1743, -97.6321)
#   Found 2 restaurants (2 new) - Total unique: 388
# Searching grid point 84/391: (30.1743, -97.6102)
#   Found 10 restaurants (8 new) - Total unique: 396
# Searching grid point 85/391: (30.1743, -97.5883)
#   Found 0 restaurants (0 new) - Total unique: 396
# Searching grid point 86/391: (30.1932, -97.9383)
#   Found 0 restaurants (0 new) - Total unique: 396
# Searching grid point 87/391: (30.1932, -97.9164)
#   Found 1 restaurants (0 new) - Total unique: 396
# Searching grid point 88/391: (30.1932, -97.8946)
#   Found 0 restaurants (0 new) - Total unique: 396
# Searching grid point 89/391: (30.1932, -97.8727)
#   Found 20 restaurants (20 new) - Total unique: 416
# Searching grid point 90/391: (30.1932, -97.8508)
#   Found 28 restaurants (10 new) - Total unique: 426
# Searching grid point 91/391: (30.1932, -97.8289)
#   Found 18 restaurants (8 new) - Total unique: 434
# Searching grid point 92/391: (30.1932, -97.8071)
#   Found 16 restaurants (14 new) - Total unique: 448
# Searching grid point 93/391: (30.1932, -97.7852)
#   Found 60 restaurants (50 new) - Total unique: 498
# Searching grid point 94/391: (30.1932, -97.7633)
#   Found 58 restaurants (32 new) - Total unique: 530
# Searching grid point 95/391: (30.1932, -97.7414)
#   Found 15 restaurants (14 new) - Total unique: 544
# Searching grid point 96/391: (30.1932, -97.7196)
#   Found 10 restaurants (10 new) - Total unique: 554
# Searching grid point 97/391: (30.1932, -97.6977)
#   Found 8 restaurants (4 new) - Total unique: 558
# Searching grid point 98/391: (30.1932, -97.6758)
#   Found 30 restaurants (29 new) - Total unique: 587
# Searching grid point 99/391: (30.1932, -97.6539)
#   Found 11 restaurants (5 new) - Total unique: 592
# Searching grid point 100/391: (30.1932, -97.6321)
#   Found 0 restaurants (0 new) - Total unique: 592
# Searching grid point 101/391: (30.1932, -97.6102)
#   Found 4 restaurants (1 new) - Total unique: 593
# Searching grid point 102/391: (30.1932, -97.5883)
#   Found 0 restaurants (0 new) - Total unique: 593
# Searching grid point 103/391: (30.2121, -97.9383)
#   Found 0 restaurants (0 new) - Total unique: 593
# Searching grid point 104/391: (30.2121, -97.9164)
#   Found 0 restaurants (0 new) - Total unique: 593
# Searching grid point 105/391: (30.2121, -97.8946)
#   Found 0 restaurants (0 new) - Total unique: 593
# Searching grid point 106/391: (30.2121, -97.8727)
#   Found 14 restaurants (0 new) - Total unique: 593
# Searching grid point 107/391: (30.2121, -97.8508)
#   Found 11 restaurants (11 new) - Total unique: 604
# Searching grid point 108/391: (30.2121, -97.8289)
#   Found 50 restaurants (42 new) - Total unique: 646
# Searching grid point 109/391: (30.2121, -97.8071)
#   Found 44 restaurants (21 new) - Total unique: 667
# Searching grid point 110/391: (30.2121, -97.7852)
#   Found 53 restaurants (33 new) - Total unique: 700
# Searching grid point 111/391: (30.2121, -97.7633)
#   Found 60 restaurants (47 new) - Total unique: 747
# Searching grid point 112/391: (30.2121, -97.7414)
#   Found 41 restaurants (34 new) - Total unique: 781
# Searching grid point 113/391: (30.2121, -97.7196)
#   Found 50 restaurants (24 new) - Total unique: 805
# Searching grid point 114/391: (30.2121, -97.6977)
#   Found 36 restaurants (29 new) - Total unique: 834
# Searching grid point 115/391: (30.2121, -97.6758)
#   Found 44 restaurants (8 new) - Total unique: 842
# Searching grid point 116/391: (30.2121, -97.6539)
#   Found 25 restaurants (12 new) - Total unique: 854
# Searching grid point 117/391: (30.2121, -97.6321)
#   Found 6 restaurants (2 new) - Total unique: 856
# Searching grid point 118/391: (30.2121, -97.6102)
#   Found 0 restaurants (0 new) - Total unique: 856
# Searching grid point 119/391: (30.2121, -97.5883)
#   Found 0 restaurants (0 new) - Total unique: 856
# Searching grid point 120/391: (30.2310, -97.9383)
#   Found 6 restaurants (6 new) - Total unique: 862
# Searching grid point 121/391: (30.2310, -97.9164)
#   Found 9 restaurants (5 new) - Total unique: 867
# Searching grid point 122/391: (30.2310, -97.8946)
#   Found 1 restaurants (1 new) - Total unique: 868
# Searching grid point 123/391: (30.2310, -97.8727)
#   Found 23 restaurants (22 new) - Total unique: 890
# Searching grid point 124/391: (30.2310, -97.8508)
#   Found 36 restaurants (21 new) - Total unique: 911
# Searching grid point 125/391: (30.2310, -97.8289)
#   Found 60 restaurants (33 new) - Total unique: 944
# Searching grid point 126/391: (30.2310, -97.8071)
#   Found 52 restaurants (26 new) - Total unique: 970
# Searching grid point 127/391: (30.2310, -97.7852)
#   Found 60 restaurants (46 new) - Total unique: 1016
# Searching grid point 128/391: (30.2310, -97.7633)
#   Found 60 restaurants (45 new) - Total unique: 1061
# Searching grid point 129/391: (30.2310, -97.7414)
#   Found 56 restaurants (46 new) - Total unique: 1107
# Searching grid point 130/391: (30.2310, -97.7196)
#   Found 60 restaurants (38 new) - Total unique: 1145
# Searching grid point 131/391: (30.2310, -97.6977)
#   Found 32 restaurants (19 new) - Total unique: 1164
# Searching grid point 132/391: (30.2310, -97.6758)
#   Found 6 restaurants (0 new) - Total unique: 1164
# Searching grid point 133/391: (30.2310, -97.6539)
#   Found 2 restaurants (0 new) - Total unique: 1164
# Searching grid point 134/391: (30.2310, -97.6321)
#   Found 2 restaurants (0 new) - Total unique: 1164
# Searching grid point 135/391: (30.2310, -97.6102)
#   Found 0 restaurants (0 new) - Total unique: 1164
# Searching grid point 136/391: (30.2310, -97.5883)
#   Found 0 restaurants (0 new) - Total unique: 1164
# Searching grid point 137/391: (30.2500, -97.9383)
#   Found 2 restaurants (2 new) - Total unique: 1166
# Searching grid point 138/391: (30.2500, -97.9164)
#   Found 5 restaurants (3 new) - Total unique: 1169
# Searching grid point 139/391: (30.2500, -97.8946)
#   Found 9 restaurants (8 new) - Total unique: 1177
# Searching grid point 140/391: (30.2500, -97.8727)
#   Found 15 restaurants (10 new) - Total unique: 1187
# Searching grid point 141/391: (30.2500, -97.8508)
#   Found 1 restaurants (0 new) - Total unique: 1187
# Searching grid point 142/391: (30.2500, -97.8289)
#   Found 2 restaurants (0 new) - Total unique: 1187
# Searching grid point 143/391: (30.2500, -97.8071)
#   Found 15 restaurants (15 new) - Total unique: 1202
# Searching grid point 144/391: (30.2500, -97.7852)
#   Found 42 restaurants (15 new) - Total unique: 1217
# Searching grid point 145/391: (30.2500, -97.7633)
#   Found 60 restaurants (54 new) - Total unique: 1271
# Searching grid point 146/391: (30.2500, -97.7414)
#   Found 60 restaurants (40 new) - Total unique: 1311
# Searching grid point 147/391: (30.2500, -97.7196)
#   Found 60 restaurants (41 new) - Total unique: 1352
# Searching grid point 148/391: (30.2500, -97.6977)
#   Found 57 restaurants (50 new) - Total unique: 1402
# Searching grid point 149/391: (30.2500, -97.6758)
#   Found 0 restaurants (0 new) - Total unique: 1402
# Searching grid point 150/391: (30.2500, -97.6539)
#   Found 0 restaurants (0 new) - Total unique: 1402
# Searching grid point 151/391: (30.2500, -97.6321)
#   Found 0 restaurants (0 new) - Total unique: 1402
# Searching grid point 152/391: (30.2500, -97.6102)
#   Found 4 restaurants (4 new) - Total unique: 1406
# Searching grid point 153/391: (30.2500, -97.5883)
#   Found 9 restaurants (7 new) - Total unique: 1413
# Searching grid point 154/391: (30.2689, -97.9383)
#   Found 0 restaurants (0 new) - Total unique: 1413
# Searching grid point 155/391: (30.2689, -97.9164)
#   Found 2 restaurants (0 new) - Total unique: 1413
# Searching grid point 156/391: (30.2689, -97.8946)
#   Found 1 restaurants (0 new) - Total unique: 1413
# Searching grid point 157/391: (30.2689, -97.8727)
#   Found 2 restaurants (0 new) - Total unique: 1413
# Searching grid point 158/391: (30.2689, -97.8508)
#   Found 0 restaurants (0 new) - Total unique: 1413
# Searching grid point 159/391: (30.2689, -97.8289)
#   Found 7 restaurants (7 new) - Total unique: 1420
# Searching grid point 160/391: (30.2689, -97.8071)
#   Found 49 restaurants (31 new) - Total unique: 1451
# Searching grid point 161/391: (30.2689, -97.7852)
#   Found 15 restaurants (7 new) - Total unique: 1458
# Searching grid point 162/391: (30.2689, -97.7633)
#   Found 60 restaurants (47 new) - Total unique: 1505
# Searching grid point 163/391: (30.2689, -97.7414)
#   Found 60 restaurants (47 new) - Total unique: 1552
# Searching grid point 164/391: (30.2689, -97.7196)
#   Found 60 restaurants (44 new) - Total unique: 1596
# Searching grid point 165/391: (30.2689, -97.6977)
#   Found 60 restaurants (38 new) - Total unique: 1634
# Searching grid point 166/391: (30.2689, -97.6758)
#   Found 6 restaurants (4 new) - Total unique: 1638
# Searching grid point 167/391: (30.2689, -97.6539)
#   Found 2 restaurants (2 new) - Total unique: 1640
# Searching grid point 168/391: (30.2689, -97.6321)
#   Found 19 restaurants (19 new) - Total unique: 1659
# Searching grid point 169/391: (30.2689, -97.6102)
#   Found 7 restaurants (1 new) - Total unique: 1660
# Searching grid point 170/391: (30.2689, -97.5883)
#   Found 0 restaurants (0 new) - Total unique: 1660
# Searching grid point 171/391: (30.2878, -97.9383)
#   Found 0 restaurants (0 new) - Total unique: 1660
# Searching grid point 172/391: (30.2878, -97.9164)
#   Found 0 restaurants (0 new) - Total unique: 1660
# Searching grid point 173/391: (30.2878, -97.8946)
#   Found 0 restaurants (0 new) - Total unique: 1660
# Searching grid point 174/391: (30.2878, -97.8727)
#   Found 6 restaurants (6 new) - Total unique: 1666
# Searching grid point 175/391: (30.2878, -97.8508)
#   Found 5 restaurants (0 new) - Total unique: 1666
# Searching grid point 176/391: (30.2878, -97.8289)
#   Found 25 restaurants (23 new) - Total unique: 1689
# Searching grid point 177/391: (30.2878, -97.8071)
#   Found 13 restaurants (0 new) - Total unique: 1689
# Searching grid point 178/391: (30.2878, -97.7852)
#   Found 8 restaurants (8 new) - Total unique: 1697
# Searching grid point 179/391: (30.2878, -97.7633)
#   Found 25 restaurants (11 new) - Total unique: 1708
# Searching grid point 180/391: (30.2878, -97.7414)
#   Found 60 restaurants (53 new) - Total unique: 1761
# Searching grid point 181/391: (30.2878, -97.7196)
#   Found 60 restaurants (54 new) - Total unique: 1815
# Searching grid point 182/391: (30.2878, -97.6977)
#   Found 60 restaurants (49 new) - Total unique: 1864
# Searching grid point 183/391: (30.2878, -97.6758)
#   Found 14 restaurants (8 new) - Total unique: 1872
# Searching grid point 184/391: (30.2878, -97.6539)
#   Found 12 restaurants (5 new) - Total unique: 1877
# Searching grid point 185/391: (30.2878, -97.6321)
#   Found 6 restaurants (2 new) - Total unique: 1879
# Searching grid point 186/391: (30.2878, -97.6102)
#   Found 0 restaurants (0 new) - Total unique: 1879
# Searching grid point 187/391: (30.2878, -97.5883)
#   Found 0 restaurants (0 new) - Total unique: 1879
# Searching grid point 188/391: (30.3067, -97.9383)
#   Found 50 restaurants (50 new) - Total unique: 1929
# Searching grid point 189/391: (30.3067, -97.9164)
#   Found 6 restaurants (3 new) - Total unique: 1932
# Searching grid point 190/391: (30.3067, -97.8946)
#   Found 0 restaurants (0 new) - Total unique: 1932
# Searching grid point 191/391: (30.3067, -97.8727)
#   Found 2 restaurants (2 new) - Total unique: 1934
# Searching grid point 192/391: (30.3067, -97.8508)
#   Found 4 restaurants (4 new) - Total unique: 1938
# Searching grid point 193/391: (30.3067, -97.8289)
#   Found 13 restaurants (2 new) - Total unique: 1940
# Searching grid point 194/391: (30.3067, -97.8071)
#   Found 0 restaurants (0 new) - Total unique: 1940
# Searching grid point 195/391: (30.3067, -97.7852)
#   Found 4 restaurants (2 new) - Total unique: 1942
# Searching grid point 196/391: (30.3067, -97.7633)
#   Found 16 restaurants (13 new) - Total unique: 1955
# Searching grid point 197/391: (30.3067, -97.7414)
#   Found 60 restaurants (41 new) - Total unique: 1996
# Searching grid point 198/391: (30.3067, -97.7196)
#   Found 60 restaurants (46 new) - Total unique: 2042
# Searching grid point 199/391: (30.3067, -97.6977)
#   Found 60 restaurants (36 new) - Total unique: 2078
# Searching grid point 200/391: (30.3067, -97.6758)
#   Found 25 restaurants (25 new) - Total unique: 2103
# Searching grid point 201/391: (30.3067, -97.6539)
#   Found 16 restaurants (5 new) - Total unique: 2108
# Searching grid point 202/391: (30.3067, -97.6321)
#   Found 2 restaurants (0 new) - Total unique: 2108
# Searching grid point 203/391: (30.3067, -97.6102)
#   Found 0 restaurants (0 new) - Total unique: 2108
# Searching grid point 204/391: (30.3067, -97.5883)
#   Found 0 restaurants (0 new) - Total unique: 2108
# Searching grid point 205/391: (30.3256, -97.9383)
#   Found 1 restaurants (0 new) - Total unique: 2108
# Searching grid point 206/391: (30.3256, -97.9164)
#   Found 0 restaurants (0 new) - Total unique: 2108
# Searching grid point 207/391: (30.3256, -97.8946)
#   Found 1 restaurants (1 new) - Total unique: 2109
# Searching grid point 208/391: (30.3256, -97.8727)
#   Found 5 restaurants (2 new) - Total unique: 2111
# Searching grid point 209/391: (30.3256, -97.8508)
#   Found 2 restaurants (0 new) - Total unique: 2111
# Searching grid point 210/391: (30.3256, -97.8289)
#   Found 1 restaurants (1 new) - Total unique: 2112
# Searching grid point 211/391: (30.3256, -97.8071)
#   Found 5 restaurants (5 new) - Total unique: 2117
# Searching grid point 212/391: (30.3256, -97.7852)
#   Found 0 restaurants (0 new) - Total unique: 2117
# Searching grid point 213/391: (30.3256, -97.7633)
#   Found 15 restaurants (13 new) - Total unique: 2130
# Searching grid point 214/391: (30.3256, -97.7414)
#   Found 60 restaurants (46 new) - Total unique: 2176
# Searching grid point 215/391: (30.3256, -97.7196)
#   Found 60 restaurants (47 new) - Total unique: 2223
# Searching grid point 216/391: (30.3256, -97.6977)
#   Found 60 restaurants (39 new) - Total unique: 2262
# Searching grid point 217/391: (30.3256, -97.6758)
#   Found 20 restaurants (12 new) - Total unique: 2274
# Searching grid point 218/391: (30.3256, -97.6539)
#   Found 11 restaurants (9 new) - Total unique: 2283
# Searching grid point 219/391: (30.3256, -97.6321)
#   Found 2 restaurants (2 new) - Total unique: 2285
# Searching grid point 220/391: (30.3256, -97.6102)
#   Found 2 restaurants (1 new) - Total unique: 2286
# Searching grid point 221/391: (30.3256, -97.5883)
#   Found 0 restaurants (0 new) - Total unique: 2286
# Searching grid point 222/391: (30.3445, -97.9383)
#   Found 0 restaurants (0 new) - Total unique: 2286
# Searching grid point 223/391: (30.3445, -97.9164)
#   Found 0 restaurants (0 new) - Total unique: 2286
# Searching grid point 224/391: (30.3445, -97.8946)
#   Found 0 restaurants (0 new) - Total unique: 2286
# Searching grid point 225/391: (30.3445, -97.8727)
#   Found 6 restaurants (4 new) - Total unique: 2290
# Searching grid point 226/391: (30.3445, -97.8508)
#   Found 1 restaurants (0 new) - Total unique: 2290
# Searching grid point 227/391: (30.3445, -97.8289)
#   Found 1 restaurants (0 new) - Total unique: 2290
# Searching grid point 228/391: (30.3445, -97.8071)
#   Found 7 restaurants (2 new) - Total unique: 2292
# Searching grid point 229/391: (30.3445, -97.7852)
#   Found 2 restaurants (2 new) - Total unique: 2294
# Searching grid point 230/391: (30.3445, -97.7633)
#   Found 28 restaurants (19 new) - Total unique: 2313
# Searching grid point 231/391: (30.3445, -97.7414)
#   Found 42 restaurants (37 new) - Total unique: 2350
# Searching grid point 232/391: (30.3445, -97.7196)
#   Found 58 restaurants (48 new) - Total unique: 2398
# Searching grid point 233/391: (30.3445, -97.6977)
#   Found 60 restaurants (53 new) - Total unique: 2451
# Searching grid point 234/391: (30.3445, -97.6758)
#   Found 28 restaurants (20 new) - Total unique: 2471
# Searching grid point 235/391: (30.3445, -97.6539)
#   Found 1 restaurants (1 new) - Total unique: 2472
# Searching grid point 236/391: (30.3445, -97.6321)
#   Found 1 restaurants (0 new) - Total unique: 2472
# Searching grid point 237/391: (30.3445, -97.6102)
#   Found 6 restaurants (5 new) - Total unique: 2477
# Searching grid point 238/391: (30.3445, -97.5883)
#   Found 1 restaurants (1 new) - Total unique: 2478
# Searching grid point 239/391: (30.3635, -97.9383)
#   Found 5 restaurants (5 new) - Total unique: 2483
# Searching grid point 240/391: (30.3635, -97.9164)
#   Found 0 restaurants (0 new) - Total unique: 2483
# Searching grid point 241/391: (30.3635, -97.8946)
#   Found 2 restaurants (2 new) - Total unique: 2485
# Searching grid point 242/391: (30.3635, -97.8727)
#   Found 1 restaurants (1 new) - Total unique: 2486
# Searching grid point 243/391: (30.3635, -97.8508)
#   Found 2 restaurants (1 new) - Total unique: 2487
# Searching grid point 244/391: (30.3635, -97.8289)
#   Found 0 restaurants (0 new) - Total unique: 2487
# Searching grid point 245/391: (30.3635, -97.8071)
#   Found 6 restaurants (5 new) - Total unique: 2492
# Searching grid point 246/391: (30.3635, -97.7852)
#   Found 5 restaurants (3 new) - Total unique: 2495
# Searching grid point 247/391: (30.3635, -97.7633)
#   Found 27 restaurants (14 new) - Total unique: 2509
# Searching grid point 248/391: (30.3635, -97.7414)
#   Found 60 restaurants (51 new) - Total unique: 2560
# Searching grid point 249/391: (30.3635, -97.7196)
#   Found 60 restaurants (43 new) - Total unique: 2603
# Searching grid point 250/391: (30.3635, -97.6977)
#   Found 60 restaurants (54 new) - Total unique: 2657
# Searching grid point 251/391: (30.3635, -97.6758)
#   Found 60 restaurants (48 new) - Total unique: 2705
# Searching grid point 252/391: (30.3635, -97.6539)
#   Found 0 restaurants (0 new) - Total unique: 2705
# Searching grid point 253/391: (30.3635, -97.6321)
#   Found 2 restaurants (2 new) - Total unique: 2707
# Searching grid point 254/391: (30.3635, -97.6102)
#   Found 3 restaurants (3 new) - Total unique: 2710
# Searching grid point 255/391: (30.3635, -97.5883)
#   Found 0 restaurants (0 new) - Total unique: 2710
# Searching grid point 256/391: (30.3824, -97.9383)
#   Found 6 restaurants (5 new) - Total unique: 2715
# Searching grid point 257/391: (30.3824, -97.9164)
#   Found 2 restaurants (0 new) - Total unique: 2715
# Searching grid point 258/391: (30.3824, -97.8946)
#   Found 15 restaurants (13 new) - Total unique: 2728
# Searching grid point 259/391: (30.3824, -97.8727)
#   Found 12 restaurants (4 new) - Total unique: 2732
# Searching grid point 260/391: (30.3824, -97.8508)
#   Found 5 restaurants (5 new) - Total unique: 2737
# Searching grid point 261/391: (30.3824, -97.8289)
#   Found 0 restaurants (0 new) - Total unique: 2737
# Searching grid point 262/391: (30.3824, -97.8071)
#   Found 1 restaurants (0 new) - Total unique: 2737
# Searching grid point 263/391: (30.3824, -97.7852)
#   Found 0 restaurants (0 new) - Total unique: 2737
# Searching grid point 264/391: (30.3824, -97.7633)
#   Found 15 restaurants (3 new) - Total unique: 2740
# Searching grid point 265/391: (30.3824, -97.7414)
#   Found 44 restaurants (41 new) - Total unique: 2781
# Searching grid point 266/391: (30.3824, -97.7196)
#   Found 60 restaurants (41 new) - Total unique: 2822
# Searching grid point 267/391: (30.3824, -97.6977)
#   Found 60 restaurants (56 new) - Total unique: 2878
# Searching grid point 268/391: (30.3824, -97.6758)
#   Found 60 restaurants (28 new) - Total unique: 2906
# Searching grid point 269/391: (30.3824, -97.6539)
#   Found 20 restaurants (20 new) - Total unique: 2926
# Searching grid point 270/391: (30.3824, -97.6321)
#   Found 2 restaurants (1 new) - Total unique: 2927
# Searching grid point 271/391: (30.3824, -97.6102)
#   Found 1 restaurants (0 new) - Total unique: 2927
# Searching grid point 272/391: (30.3824, -97.5883)
#   Found 0 restaurants (0 new) - Total unique: 2927
# Searching grid point 273/391: (30.4013, -97.9383)
#   Found 13 restaurants (12 new) - Total unique: 2939
# Searching grid point 274/391: (30.4013, -97.9164)
#   Found 8 restaurants (0 new) - Total unique: 2939
# Searching grid point 275/391: (30.4013, -97.8946)
#   Found 4 restaurants (0 new) - Total unique: 2939
# Searching grid point 276/391: (30.4013, -97.8727)
#   Found 6 restaurants (3 new) - Total unique: 2942
# Searching grid point 277/391: (30.4013, -97.8508)
#   Found 40 restaurants (35 new) - Total unique: 2977
# Searching grid point 278/391: (30.4013, -97.8289)
#   Found 0 restaurants (0 new) - Total unique: 2977
# Searching grid point 279/391: (30.4013, -97.8071)
#   Found 0 restaurants (0 new) - Total unique: 2977
# Searching grid point 280/391: (30.4013, -97.7852)
#   Found 0 restaurants (0 new) - Total unique: 2977
# Searching grid point 281/391: (30.4013, -97.7633)
#   Found 11 restaurants (11 new) - Total unique: 2988
# Searching grid point 282/391: (30.4013, -97.7414)
#   Found 60 restaurants (37 new) - Total unique: 3025
# Searching grid point 283/391: (30.4013, -97.7196)
#   Found 60 restaurants (48 new) - Total unique: 3073
# Searching grid point 284/391: (30.4013, -97.6977)
#   Found 23 restaurants (21 new) - Total unique: 3094
# Searching grid point 285/391: (30.4013, -97.6758)
#   Found 49 restaurants (49 new) - Total unique: 3143
# Searching grid point 286/391: (30.4013, -97.6539)
#   Found 22 restaurants (16 new) - Total unique: 3159
# Searching grid point 287/391: (30.4013, -97.6321)
#   Found 37 restaurants (35 new) - Total unique: 3194
# Searching grid point 288/391: (30.4013, -97.6102)
#   Found 0 restaurants (0 new) - Total unique: 3194
# Searching grid point 289/391: (30.4013, -97.5883)
#   Found 0 restaurants (0 new) - Total unique: 3194
# Searching grid point 290/391: (30.4202, -97.9383)
#   Found 7 restaurants (7 new) - Total unique: 3201
# Searching grid point 291/391: (30.4202, -97.9164)
#   Found 5 restaurants (0 new) - Total unique: 3201
# Searching grid point 292/391: (30.4202, -97.8946)
#   Found 0 restaurants (0 new) - Total unique: 3201
# Searching grid point 293/391: (30.4202, -97.8727)
#   Found 0 restaurants (0 new) - Total unique: 3201
# Searching grid point 294/391: (30.4202, -97.8508)
#   Found 25 restaurants (10 new) - Total unique: 3211
# Searching grid point 295/391: (30.4202, -97.8289)
#   Found 0 restaurants (0 new) - Total unique: 3211
# Searching grid point 296/391: (30.4202, -97.8071)
#   Found 0 restaurants (0 new) - Total unique: 3211
# Searching grid point 297/391: (30.4202, -97.7852)
#   Found 0 restaurants (0 new) - Total unique: 3211
# Searching grid point 298/391: (30.4202, -97.7633)
#   Found 15 restaurants (15 new) - Total unique: 3226
# Searching grid point 299/391: (30.4202, -97.7414)
#   Found 26 restaurants (18 new) - Total unique: 3244
# Searching grid point 300/391: (30.4202, -97.7196)
#   Found 14 restaurants (12 new) - Total unique: 3256
# Searching grid point 301/391: (30.4202, -97.6977)
#   Found 56 restaurants (42 new) - Total unique: 3298
# Searching grid point 302/391: (30.4202, -97.6758)
#   Found 60 restaurants (31 new) - Total unique: 3329
# Searching grid point 303/391: (30.4202, -97.6539)
#   Found 14 restaurants (8 new) - Total unique: 3337
# Searching grid point 304/391: (30.4202, -97.6321)
#   Found 3 restaurants (2 new) - Total unique: 3339
# Searching grid point 305/391: (30.4202, -97.6102)
#   Found 0 restaurants (0 new) - Total unique: 3339
# Searching grid point 306/391: (30.4202, -97.5883)
#   Found 4 restaurants (4 new) - Total unique: 3343
# Searching grid point 307/391: (30.4391, -97.9383)
#   Found 2 restaurants (1 new) - Total unique: 3344
# Searching grid point 308/391: (30.4391, -97.9164)
#   Found 3 restaurants (3 new) - Total unique: 3347
# Searching grid point 309/391: (30.4391, -97.8946)
#   Found 0 restaurants (0 new) - Total unique: 3347
# Searching grid point 310/391: (30.4391, -97.8727)
#   Found 0 restaurants (0 new) - Total unique: 3347
# Searching grid point 311/391: (30.4391, -97.8508)
#   Found 0 restaurants (0 new) - Total unique: 3347
# Searching grid point 312/391: (30.4391, -97.8289)
#   Found 4 restaurants (4 new) - Total unique: 3351
# Searching grid point 313/391: (30.4391, -97.8071)
#   Found 12 restaurants (12 new) - Total unique: 3363
# Searching grid point 314/391: (30.4391, -97.7852)
#   Found 60 restaurants (60 new) - Total unique: 3423
# Searching grid point 315/391: (30.4391, -97.7633)
#   Found 57 restaurants (42 new) - Total unique: 3465
# Searching grid point 316/391: (30.4391, -97.7414)
#   Found 26 restaurants (16 new) - Total unique: 3481
# Searching grid point 317/391: (30.4391, -97.7196)
#   Found 0 restaurants (0 new) - Total unique: 3481
# Searching grid point 318/391: (30.4391, -97.6977)
#   Found 23 restaurants (22 new) - Total unique: 3503
# Searching grid point 319/391: (30.4391, -97.6758)
#   Found 54 restaurants (38 new) - Total unique: 3541
# Searching grid point 320/391: (30.4391, -97.6539)
#   Found 60 restaurants (33 new) - Total unique: 3574
# Searching grid point 321/391: (30.4391, -97.6321)
#   Found 29 restaurants (29 new) - Total unique: 3603
# Searching grid point 322/391: (30.4391, -97.6102)
#   Found 32 restaurants (20 new) - Total unique: 3623
# Searching grid point 323/391: (30.4391, -97.5883)
#   Found 2 restaurants (1 new) - Total unique: 3624
# Searching grid point 324/391: (30.4581, -97.9383)
#   Found 1 restaurants (0 new) - Total unique: 3624
# Searching grid point 325/391: (30.4581, -97.9164)
#   Found 1 restaurants (1 new) - Total unique: 3625
# Searching grid point 326/391: (30.4581, -97.8946)
#   Found 0 restaurants (0 new) - Total unique: 3625
# Searching grid point 327/391: (30.4581, -97.8727)
#   Found 0 restaurants (0 new) - Total unique: 3625
# Searching grid point 328/391: (30.4581, -97.8508)
#   Found 1 restaurants (1 new) - Total unique: 3626
# Searching grid point 329/391: (30.4581, -97.8289)
#   Found 41 restaurants (39 new) - Total unique: 3665
# Searching grid point 330/391: (30.4581, -97.8071)
#   Found 60 restaurants (36 new) - Total unique: 3701
# Searching grid point 331/391: (30.4581, -97.7852)
#   Found 60 restaurants (29 new) - Total unique: 3730
# Searching grid point 332/391: (30.4581, -97.7633)
#   Found 9 restaurants (8 new) - Total unique: 3738
# Searching grid point 333/391: (30.4581, -97.7414)
#   Found 10 restaurants (0 new) - Total unique: 3738
# Searching grid point 334/391: (30.4581, -97.7196)
#   Found 0 restaurants (0 new) - Total unique: 3738
# Searching grid point 335/391: (30.4581, -97.6977)
#   Found 6 restaurants (2 new) - Total unique: 3740
# Searching grid point 336/391: (30.4581, -97.6758)
#   Found 20 restaurants (19 new) - Total unique: 3759
# Searching grid point 337/391: (30.4581, -97.6539)
#   Found 60 restaurants (21 new) - Total unique: 3780
# Searching grid point 338/391: (30.4581, -97.6321)
#   Found 7 restaurants (2 new) - Total unique: 3782
# Searching grid point 339/391: (30.4581, -97.6102)
#   Found 34 restaurants (25 new) - Total unique: 3807
# Searching grid point 340/391: (30.4581, -97.5883)
#   Found 41 restaurants (23 new) - Total unique: 3830
# Searching grid point 341/391: (30.4770, -97.9383)
#   Found 0 restaurants (0 new) - Total unique: 3830
# Searching grid point 342/391: (30.4770, -97.9164)
#   Found 0 restaurants (0 new) - Total unique: 3830
# Searching grid point 343/391: (30.4770, -97.8946)
#   Found 0 restaurants (0 new) - Total unique: 3830
# Searching grid point 344/391: (30.4770, -97.8727)
#   Found 0 restaurants (0 new) - Total unique: 3830
# Searching grid point 345/391: (30.4770, -97.8508)
#   Found 7 restaurants (7 new) - Total unique: 3837
# Searching grid point 346/391: (30.4770, -97.8289)
#   Found 45 restaurants (38 new) - Total unique: 3875
# Searching grid point 347/391: (30.4770, -97.8071)
#   Found 60 restaurants (48 new) - Total unique: 3923
# Searching grid point 348/391: (30.4770, -97.7852)
#   Found 47 restaurants (19 new) - Total unique: 3942
# Searching grid point 349/391: (30.4770, -97.7633)
#   Found 12 restaurants (10 new) - Total unique: 3952
# Searching grid point 350/391: (30.4770, -97.7414)
#   Found 3 restaurants (3 new) - Total unique: 3955
# Searching grid point 351/391: (30.4770, -97.7196)
#   Found 0 restaurants (0 new) - Total unique: 3955
# Searching grid point 352/391: (30.4770, -97.6977)
#   Found 13 restaurants (11 new) - Total unique: 3966
# Searching grid point 353/391: (30.4770, -97.6758)
#   Found 60 restaurants (55 new) - Total unique: 4021
# Searching grid point 354/391: (30.4770, -97.6539)
#   Found 29 restaurants (25 new) - Total unique: 4046
# Searching grid point 355/391: (30.4770, -97.6321)
#   Found 5 restaurants (0 new) - Total unique: 4046
# Searching grid point 356/391: (30.4770, -97.6102)
#   Found 6 restaurants (5 new) - Total unique: 4051
# Searching grid point 357/391: (30.4770, -97.5883)
#   Found 32 restaurants (8 new) - Total unique: 4059
# Searching grid point 358/391: (30.4959, -97.9383)
#   Found 5 restaurants (5 new) - Total unique: 4064
# Searching grid point 359/391: (30.4959, -97.9164)
#   Found 5 restaurants (0 new) - Total unique: 4064
# Searching grid point 360/391: (30.4959, -97.8946)
#   Found 0 restaurants (0 new) - Total unique: 4064
# Searching grid point 361/391: (30.4959, -97.8727)
#   Found 0 restaurants (0 new) - Total unique: 4064
# Searching grid point 362/391: (30.4959, -97.8508)
#   Found 2 restaurants (2 new) - Total unique: 4066
# Searching grid point 363/391: (30.4959, -97.8289)
#   Found 24 restaurants (18 new) - Total unique: 4084
# Searching grid point 364/391: (30.4959, -97.8071)
#   Found 14 restaurants (1 new) - Total unique: 4085
# Searching grid point 365/391: (30.4959, -97.7852)
#   Found 21 restaurants (21 new) - Total unique: 4106
# Searching grid point 366/391: (30.4959, -97.7633)
#   Found 18 restaurants (2 new) - Total unique: 4108
# Searching grid point 367/391: (30.4959, -97.7414)
#   Found 4 restaurants (1 new) - Total unique: 4109
# Searching grid point 368/391: (30.4959, -97.7196)
#   Found 21 restaurants (20 new) - Total unique: 4129
# Searching grid point 369/391: (30.4959, -97.6977)
#   Found 3 restaurants (3 new) - Total unique: 4132
# Searching grid point 370/391: (30.4959, -97.6758)
#   Found 60 restaurants (49 new) - Total unique: 4181
# Searching grid point 371/391: (30.4959, -97.6539)
#   Found 28 restaurants (19 new) - Total unique: 4200
# Searching grid point 372/391: (30.4959, -97.6321)
#   Found 4 restaurants (2 new) - Total unique: 4202
# Searching grid point 373/391: (30.4959, -97.6102)
#   Found 15 restaurants (12 new) - Total unique: 4214
# Searching grid point 374/391: (30.4959, -97.5883)
#   Found 30 restaurants (28 new) - Total unique: 4242
# Searching grid point 375/391: (30.5148, -97.9383)
#   Found 0 restaurants (0 new) - Total unique: 4242
# Searching grid point 376/391: (30.5148, -97.9164)
#   Found 1 restaurants (1 new) - Total unique: 4243
# Searching grid point 377/391: (30.5148, -97.8946)
#   Found 1 restaurants (1 new) - Total unique: 4244
# Searching grid point 378/391: (30.5148, -97.8727)
#   Found 10 restaurants (9 new) - Total unique: 4253
# Searching grid point 379/391: (30.5148, -97.8508)
#   Found 12 restaurants (12 new) - Total unique: 4265
# Searching grid point 380/391: (30.5148, -97.8289)
#   Found 60 restaurants (59 new) - Total unique: 4324
# Searching grid point 381/391: (30.5148, -97.8071)
#   Found 21 restaurants (21 new) - Total unique: 4345
# Searching grid point 382/391: (30.5148, -97.7852)
#   Found 22 restaurants (14 new) - Total unique: 4359
# Searching grid point 383/391: (30.5148, -97.7633)
#   Found 5 restaurants (0 new) - Total unique: 4359
# Searching grid point 384/391: (30.5148, -97.7414)
#   Found 3 restaurants (3 new) - Total unique: 4362
# Searching grid point 385/391: (30.5148, -97.7196)
#   Found 11 restaurants (0 new) - Total unique: 4362
# Searching grid point 386/391: (30.5148, -97.6977)
#   Found 52 restaurants (51 new) - Total unique: 4413
# Searching grid point 387/391: (30.5148, -97.6758)
#   Found 60 restaurants (20 new) - Total unique: 4433
# Searching grid point 388/391: (30.5148, -97.6539)
#   Found 30 restaurants (19 new) - Total unique: 4452
# Searching grid point 389/391: (30.5148, -97.6321)
#   Found 23 restaurants (22 new) - Total unique: 4474
# Searching grid point 390/391: (30.5148, -97.6102)
#   Found 2 restaurants (0 new) - Total unique: 4474
# Searching grid point 391/391: (30.5148, -97.5883)
#   Found 9 restaurants (1 new) - Total unique: 4475
#
# ✓ Total unique restaurants found: 4475
#
# ============================================================
# SEARCH COMPLETE: 4475 unique restaurants found
# ============================================================

# %% [markdown]
# Fetch details for all restaurants

# %%
print(f"\nFetching details for {len(place_ids)} restaurants...")
print("This will take a while... grab some coffee! ☕")
print("=" * 60)

all_data = []
total = len(place_ids)
errors = 0

for i, place_id in enumerate(place_ids, 1):
    if i % 50 == 0:  # Progress update every 50 restaurants
        elapsed_pct = i / total * 100
        print(f"Progress: {i}/{total} ({elapsed_pct:.1f}%) - Errors: {errors}")
    
    details = scraper.get_place_details(place_id)
    
    if details:
        flattened = scraper.flatten_restaurant_data(details)
        all_data.append(flattened)
    else:
        errors += 1
    
    # Rate limiting: avoid hitting API limits
    time.sleep(0.1)

print(f"\n{'='*60}")
print(f"DETAILS FETCH COMPLETE")
print(f"Successfully collected: {len(all_data)} restaurants")
print(f"Errors: {errors}")
print(f"{'='*60}")
# Out:
# Fetching details for 4475 restaurants...
# This will take a while... grab some coffee! ☕
# ============================================================
# Progress: 50/4475 (1.1%) - Errors: 0
# Progress: 100/4475 (2.2%) - Errors: 0
# Progress: 150/4475 (3.4%) - Errors: 0
# Progress: 200/4475 (4.5%) - Errors: 0
# Progress: 250/4475 (5.6%) - Errors: 0
# Progress: 300/4475 (6.7%) - Errors: 0
# Progress: 350/4475 (7.8%) - Errors: 0
# Progress: 400/4475 (8.9%) - Errors: 0
# Progress: 450/4475 (10.1%) - Errors: 0
# Progress: 500/4475 (11.2%) - Errors: 0
# Progress: 550/4475 (12.3%) - Errors: 0
# Progress: 600/4475 (13.4%) - Errors: 0
# Progress: 650/4475 (14.5%) - Errors: 0
# Progress: 700/4475 (15.6%) - Errors: 0
# Progress: 750/4475 (16.8%) - Errors: 0
# Progress: 800/4475 (17.9%) - Errors: 0
# Progress: 850/4475 (19.0%) - Errors: 0
# Progress: 900/4475 (20.1%) - Errors: 0
# Progress: 950/4475 (21.2%) - Errors: 0
# Progress: 1000/4475 (22.3%) - Errors: 0
# Progress: 1050/4475 (23.5%) - Errors: 0
# Progress: 1100/4475 (24.6%) - Errors: 0
# Progress: 1150/4475 (25.7%) - Errors: 0
# Progress: 1200/4475 (26.8%) - Errors: 0
# Progress: 1250/4475 (27.9%) - Errors: 0
# Progress: 1300/4475 (29.1%) - Errors: 0
# Progress: 1350/4475 (30.2%) - Errors: 0
# Progress: 1400/4475 (31.3%) - Errors: 0
# Progress: 1450/4475 (32.4%) - Errors: 0
# Progress: 1500/4475 (33.5%) - Errors: 0
# Progress: 1550/4475 (34.6%) - Errors: 0
# Progress: 1600/4475 (35.8%) - Errors: 0
# Progress: 1650/4475 (36.9%) - Errors: 0
# Progress: 1700/4475 (38.0%) - Errors: 0
# Progress: 1750/4475 (39.1%) - Errors: 0
# Progress: 1800/4475 (40.2%) - Errors: 0
# Progress: 1850/4475 (41.3%) - Errors: 0
# Progress: 1900/4475 (42.5%) - Errors: 0
# Progress: 1950/4475 (43.6%) - Errors: 0
# Progress: 2000/4475 (44.7%) - Errors: 0
# Progress: 2050/4475 (45.8%) - Errors: 0
# Progress: 2100/4475 (46.9%) - Errors: 0
# Progress: 2150/4475 (48.0%) - Errors: 0
# Progress: 2200/4475 (49.2%) - Errors: 0
# Progress: 2250/4475 (50.3%) - Errors: 0
# Progress: 2300/4475 (51.4%) - Errors: 0
# Progress: 2350/4475 (52.5%) - Errors: 0
# Progress: 2400/4475 (53.6%) - Errors: 0
# Progress: 2450/4475 (54.7%) - Errors: 0
# Progress: 2500/4475 (55.9%) - Errors: 0
# Progress: 2550/4475 (57.0%) - Errors: 0
# Progress: 2600/4475 (58.1%) - Errors: 0
# Progress: 2650/4475 (59.2%) - Errors: 0
# Progress: 2700/4475 (60.3%) - Errors: 0
# Progress: 2750/4475 (61.5%) - Errors: 0
# Progress: 2800/4475 (62.6%) - Errors: 0
# Progress: 2850/4475 (63.7%) - Errors: 0
# Progress: 2900/4475 (64.8%) - Errors: 0
# Progress: 2950/4475 (65.9%) - Errors: 0
# Progress: 3000/4475 (67.0%) - Errors: 0
# Progress: 3050/4475 (68.2%) - Errors: 0
# Progress: 3100/4475 (69.3%) - Errors: 0
# Progress: 3150/4475 (70.4%) - Errors: 0
# Progress: 3200/4475 (71.5%) - Errors: 0
# Progress: 3250/4475 (72.6%) - Errors: 0
# Progress: 3300/4475 (73.7%) - Errors: 0
# Progress: 3350/4475 (74.9%) - Errors: 0
# Progress: 3400/4475 (76.0%) - Errors: 0
# Progress: 3450/4475 (77.1%) - Errors: 0
# Progress: 3500/4475 (78.2%) - Errors: 0
# Progress: 3550/4475 (79.3%) - Errors: 0
# Progress: 3600/4475 (80.4%) - Errors: 0
# Progress: 3650/4475 (81.6%) - Errors: 0
# Progress: 3700/4475 (82.7%) - Errors: 0
# Progress: 3750/4475 (83.8%) - Errors: 0
# Progress: 3800/4475 (84.9%) - Errors: 0
# Progress: 3850/4475 (86.0%) - Errors: 0
# Progress: 3900/4475 (87.2%) - Errors: 0
# Progress: 3950/4475 (88.3%) - Errors: 0
# Progress: 4000/4475 (89.4%) - Errors: 0
# Progress: 4050/4475 (90.5%) - Errors: 0
# Progress: 4100/4475 (91.6%) - Errors: 0
# Progress: 4150/4475 (92.7%) - Errors: 0
# Progress: 4200/4475 (93.9%) - Errors: 0
# Progress: 4250/4475 (95.0%) - Errors: 0
# Progress: 4300/4475 (96.1%) - Errors: 0
# Progress: 4350/4475 (97.2%) - Errors: 0
# Progress: 4400/4475 (98.3%) - Errors: 0
# Progress: 4450/4475 (99.4%) - Errors: 0
#
# ============================================================
# DETAILS FETCH COMPLETE
# Successfully collected: 4475 restaurants
# Errors: 0
# ============================================================

# %% [markdown]
# Create DataFrame

# %%
df = pd.DataFrame(all_data)
print(f"\nDataFrame shape: {df.shape}")
print(f"Columns: {df.shape[1]}")
print(f"Rows: {df.shape[0]}")
df.head()
# Out:
# DataFrame shape: (4475, 26)
# Columns: 26
# Rows: 4475
#                       place_id                         name  \
# 0  ChIJBcwG1ZdKW4YR4H9Pg5TYwvU  Blenders & Bowls - Westlake
# 1  ChIJWW1mSSPPRIYRriBy7jZ9QgY                      Tsukimi
# 2  ChIJsx9cWey1RIYRpeZVdPR4YtA                      Dai Due
# 3  ChIJGWZOawDPRIYRwl7b7ig83Dw      El Sazón de mi Ranchito
# 4  ChIJDbkBfpLORIYRDBrzDsV7VA4          The Rolling Rooster
#
#                                    formatted_address  \
# 0  3736 Bee Caves Rd Suite 8, West Lake Hills, TX...
# 1  12400 N Interstate Hwy 35 A-111, Austin, TX 78...
# 2               2406 Manor Rd, Austin, TX 78722, USA
# 3       100 W Howard Ln, Pflugerville, TX 78660, USA
# 4      13717 Mopac Service Rd, Austin, TX 78727, USA
#
#                                   address_components        lat        lng  \
# 0  [{"long_name": "Suite 8", "short_name": "Suite...  30.280914 -97.807242
# 1  [{"long_name": "A-111", "short_name": "A-111",...  30.404119 -97.676021
# 2  [{"long_name": "2406", "short_name": "2406", "...  30.284850 -97.716756
# 3  [{"long_name": "100", "short_name": "100", "ty...  30.417858 -97.657407
# 4  [{"long_name": "13717", "short_name": "13717",...  30.437726 -97.697842
#
#                                      vicinity  \
# 0  3736 Bee Caves Rd Suite 8, West Lake Hills
# 1     12400 N Interstate Hwy 35 A-111, Austin
# 2                       2406 Manor Rd, Austin
# 3               100 W Howard Ln, Pflugerville
# 4              13717 Mopac Service Rd, Austin
#
#                                                types business_status  rating  \
# 0  ["establishment", "food", "point_of_interest",...     OPERATIONAL     4.2
# 1  ["establishment", "food", "point_of_interest",...     OPERATIONAL     4.2
# 2  ["establishment", "food", "point_of_interest",...     OPERATIONAL     4.7
# 3  ["establishment", "food", "health", "point_of_...     OPERATIONAL     NaN
# 4  ["establishment", "food", "point_of_interest",...     OPERATIONAL     4.3
#
#    ...  serves_beer  serves_wine dine_in takeout curbside_pickup delivery  \
# 0  ...        False        False    True    True            None     True
# 1  ...         True         True    True    True            True     True
# 2  ...         True         True    True    True            None    False
# 3  ...         None         None    None    None            None     None
# 4  ...         True         True    True    True           False     True
#
#   reservable                                  editorial_summary  \
# 0      False  Health-conscious cafe serving smoothies & acai...
# 1       True  Modern, low-key sushi house plating artful ren...
# 2       True  Farm-to-table fare from locally sourced ingred...
# 3       None                                               None
# 4      False  Chicken & waffles highlight the menu at this c...
#
#                                              reviews  \
# 0  [{"rating": 5, "text": "My favorite place to g...
# 1  [{"rating": 4, "text": "The food was surprisin...
# 2  [{"rating": 5, "text": "Amazing food; especial...
# 3                                                 []
# 4  [{"rating": 2, "text": "The tenders, fries and...
#
#                                               photos
# 0  [{"photo_reference": "AciIO2ew_BLTCnbFrsWweBvb...
# 1  [{"photo_reference": "AciIO2egB6RISDznN5oMd7x3...
# 2  [{"photo_reference": "AciIO2fzIWEDXEL7EOYUT8cD...
# 3  [{"photo_reference": "AciIO2dPyDXb_zhnZ-5-4yo7...
# 4  [{"photo_reference": "AciIO2cFtzHjJLhXRXRwjHFI...
#
# [5 rows x 26 columns]

# %% [markdown]
# Save to CSV

# %%
output_file = "data/austin_restaurants_full.csv"
df.to_csv(output_file, index=False)
print(f"✓ Saved to {output_file}")
# Out:
# ✓ Saved to austin_restaurants_full.csv

# %% [markdown]
# Calculate cost

# %%
# Cell 10: Calculate actual cost
details_calls = len(all_data)

# Calculate nearby searches (need to regenerate grid to count)
grid_point_count = len(scraper.generate_grid_points(austin_bounds, 1.5))
nearby_searches = grid_point_count * 3  # 3 pages per grid point average

nearby_cost = nearby_searches * 0.017
details_cost = details_calls * 0.025
total_cost = nearby_cost + details_cost

print("\n" + "=" * 60)
print("COST BREAKDOWN")
print("=" * 60)
print(f"Nearby Search calls: {nearby_searches} × $0.017 = ${nearby_cost:.2f}")
print(f"Place Details calls: {details_calls} × $0.025 = ${details_cost:.2f}")
print(f"TOTAL ESTIMATED COST: ${total_cost:.2f}")
print(f"Remaining credit: ${300 - total_cost:.2f}")
print("=" * 60)
# Out:
# Generated 391 grid points with 1.5km radius
#
# ============================================================
# COST BREAKDOWN
# ============================================================
# Nearby Search calls: 1173 × $0.017 = $19.94
# Place Details calls: 4475 × $0.025 = $111.88
# TOTAL ESTIMATED COST: $131.82
# Remaining credit: $168.18
# ============================================================

# %% [markdown]
# Data Quality Overview

# %%
print("\n" + "=" * 60)
print("DATASET OVERVIEW")
print("=" * 60)
print(f"Total restaurants: {len(df)}")
print(f"Average rating: {df['rating'].mean():.2f}")
print(f"Total reviews: {df['user_ratings_total'].sum():,}")
print(f"\nRestaurants with ratings: {df['rating'].notna().sum()} ({df['rating'].notna().sum()/len(df)*100:.1f}%)")
print(f"Restaurants with websites: {df['website'].notna().sum()} ({df['website'].notna().sum()/len(df)*100:.1f}%)")

print(f"\nPrice level distribution:")
print(df['price_level'].value_counts().sort_index())

print(f"\nBusiness status:")
print(df['business_status'].value_counts())
# Out:
# ============================================================
# DATASET OVERVIEW
# ============================================================
# Total restaurants: 4475
# Average rating: 4.22
# Total reviews: 3,042,131.0
#
# Restaurants with ratings: 4233 (94.6%)
# Restaurants with websites: 3579 (80.0%)
#
# Price level distribution:
# price_level
# 1.0    1606
# 2.0    1282
# 3.0      59
# 4.0      11
# Name: count, dtype: int64
#
# Business status:
# business_status
# OPERATIONAL           4282
# CLOSED_TEMPORARILY     193
# Name: count, dtype: int64

# %% [markdown]
# Photo and review statistics

# %%
def count_items(json_str):
    if pd.isna(json_str):
        return 0
    try:
        return len(json.loads(json_str))
    except:
        return 0

df['photo_count'] = df['photos'].apply(count_items)
df['review_count'] = df['reviews'].apply(count_items)

print(f"\n" + "=" * 60)
print("PHOTOS & REVIEWS")
print("=" * 60)
print(f"Total photos available: {df['photo_count'].sum():,}")
print(f"Average photos per restaurant: {df['photo_count'].mean():.1f}")
print(f"Restaurants with photos: {(df['photo_count'] > 0).sum()} ({(df['photo_count'] > 0).sum()/len(df)*100:.1f}%)")

print(f"\nTotal reviews in dataset: {df['review_count'].sum():,}")
print(f"Average reviews per restaurant: {df['review_count'].mean():.1f}")
print(f"Restaurants with reviews: {(df['review_count'] > 0).sum()} ({(df['review_count'] > 0).sum()/len(df)*100:.1f}%)")
# Out:
# ============================================================
# PHOTOS & REVIEWS
# ============================================================
# Total photos available: 39,970
# Average photos per restaurant: 8.9
# Restaurants with photos: 4241 (94.8%)
#
# Total reviews in dataset: 20,500
# Average reviews per restaurant: 4.6
# Restaurants with reviews: 4233 (94.6%)

# %% [markdown]
# Geographic distribution

# %%
print(f"\n" + "=" * 60)
print("GEOGRAPHIC COVERAGE")
print("=" * 60)
print(f"Latitude range: {df['lat'].min():.4f} to {df['lat'].max():.4f}")
print(f"Longitude range: {df['lng'].min():.4f} to {df['lng'].max():.4f}")
print("\nTop neighborhoods by restaurant count:")
print(df['vicinity'].value_counts().head(10))
# Out:
# ============================================================
# GEOGRAPHIC COVERAGE
# ============================================================
# Latitude range: 30.0863 to 30.5281
# Longitude range: -97.9508 to -97.5749
#
# Top neighborhoods by restaurant count:
# vicinity
# Barbara Jordan Terminal, 3600 Presidential Blvd, Austin    25
# Austin                                                     22
# 9313 Anderson Mill Rd, Austin                              17
# 510 E Anderson Ln, Austin                                  16
# 13525 Dessau Rd, Pflugerville                              11
# 8624 FM812, Austin                                         11
# 13422 Dessau Rd, Austin                                    11
# 2103 W Slaughter Ln, Austin                                10
# 7800 S 1st St, Austin                                      10
# 7221 McNeil Dr, Austin                                      9
# Name: count, dtype: int64

# %%
test_reviews = df[:1]['reviews'][0]

test_reviews
# Out:
# '[{"rating": 5, "text": "My favorite place to grab an acai bowl! The girls who work there are so kind. Always quick and great service.", "author_name": "michelle andrea", "time": 1750213545, "relative_time_description": "4 months ago"}, {"rating": 5, "text": "Honestly fantastic. Im surprised by the current rating tbh. I got a kiwi bowl but id just say thay judging by the quality of the bowl, their ingredients are top quality too and the atmosphere was very chill too \\ud83d\\ude0a. Ill be returning for sure.", "author_name": "Ryan Michels", "time": 1753127419, "relative_time_description": "2 months ago"}, {"rating": 1, "text": "Not accepting cash in 2025 should be criminal. Not to mention there is NO signage anywhere on the front door or near the cash register that states they don\\u2019t accept cash.", "author_name": "Lin", "time": 1745540862, "relative_time_description": "5 months ago"}, {"rating": 4, "text": "Got the golden oats seasonal special. It was super yummy, warm, not too sweet. I like the concept and will definitely try another flavor. The interior was super clean, almost sterile, especially compared to a place like Daily Juice, which has loads of personality. Friendly staff and great selection though. The biggest shortcoming? Coffee and espresso drinks are terrible. Definitely not their strong point. Great for health-food lovers and vegans.", "author_name": "Elizabeth Moulin-Franco", "time": 1550598293, "relative_time_description": "6 years ago"}, {"rating": 3, "text": "Taste pretty good but 3 stars should have been 2....took over 10 min to put this in a bowl. 3-5 ppl at the place and 10 min to make this.....no bueno", "author_name": "Steven Rosenthal", "time": 1506780711, "relative_time_description": "8 years ago"}]'

# %%
# Parse just the first restaurant's reviews
import json

reviews_list = json.loads(df['reviews'][0])

print(f"Number of reviews: {len(reviews_list)}")
print(f"\nAll reviews:")
for i, review in enumerate(reviews_list, 1):
    print(f"\nReview {i}:")
    print(f"  Rating: {review['rating']}")
    print(f"  Author: {review['author_name']}")
    print(f"  Text: {review['text'][:100]}...")
# Out:
# Number of reviews: 5
#
# All reviews:
#
# Review 1:
#   Rating: 5
#   Author: michelle andrea
#   Text: My favorite place to grab an acai bowl! The girls who work there are so kind. Always quick and great...
#
# Review 2:
#   Rating: 5
#   Author: Ryan Michels
#   Text: Honestly fantastic. Im surprised by the current rating tbh. I got a kiwi bowl but id just say thay j...
#
# Review 3:
#   Rating: 1
#   Author: Lin
#   Text: Not accepting cash in 2025 should be criminal. Not to mention there is NO signage anywhere on the fr...
#
# Review 4:
#   Rating: 4
#   Author: Elizabeth Moulin-Franco
#   Text: Got the golden oats seasonal special. It was super yummy, warm, not too sweet. I like the concept an...
#
# Review 5:
#   Rating: 3
#   Author: Steven Rosenthal
#   Text: Taste pretty good but 3 stars should have been 2....took over 10 min to put this in a bowl. 3-5 ppl ...

# %%
test_df = pd.read_csv("data/austin_restaurants_full.csv")

# %%
test_df.head()

# test_df[:1]['types'].to_string(index=False)

# print(repr(test_df['types'].iloc[2]))

#unique_vals = test_df['types'][test_df['types'].str.contains('restaurant', case=False)].unique()

#print(unique_vals)
# Out:
#                       place_id                         name  \
# 0  ChIJBcwG1ZdKW4YR4H9Pg5TYwvU  Blenders & Bowls - Westlake
# 1  ChIJWW1mSSPPRIYRriBy7jZ9QgY                      Tsukimi
# 2  ChIJsx9cWey1RIYRpeZVdPR4YtA                      Dai Due
# 3  ChIJGWZOawDPRIYRwl7b7ig83Dw      El Sazón de mi Ranchito
# 4  ChIJDbkBfpLORIYRDBrzDsV7VA4          The Rolling Rooster
#
#                                    formatted_address  \
# 0  3736 Bee Caves Rd Suite 8, West Lake Hills, TX...
# 1  12400 N Interstate Hwy 35 A-111, Austin, TX 78...
# 2               2406 Manor Rd, Austin, TX 78722, USA
# 3       100 W Howard Ln, Pflugerville, TX 78660, USA
# 4      13717 Mopac Service Rd, Austin, TX 78727, USA
#
#                                   address_components        lat        lng  \
# 0  [{"long_name": "Suite 8", "short_name": "Suite...  30.280914 -97.807242
# 1  [{"long_name": "A-111", "short_name": "A-111",...  30.404119 -97.676021
# 2  [{"long_name": "2406", "short_name": "2406", "...  30.284850 -97.716756
# 3  [{"long_name": "100", "short_name": "100", "ty...  30.417858 -97.657407
# 4  [{"long_name": "13717", "short_name": "13717",...  30.437726 -97.697842
#
#                                      vicinity  \
# 0  3736 Bee Caves Rd Suite 8, West Lake Hills
# 1     12400 N Interstate Hwy 35 A-111, Austin
# 2                       2406 Manor Rd, Austin
# 3               100 W Howard Ln, Pflugerville
# 4              13717 Mopac Service Rd, Austin
#
#                                                types business_status  rating  \
# 0  ["establishment", "food", "point_of_interest",...     OPERATIONAL     4.2
# 1  ["establishment", "food", "point_of_interest",...     OPERATIONAL     4.2
# 2  ["establishment", "food", "point_of_interest",...     OPERATIONAL     4.7
# 3  ["establishment", "food", "health", "point_of_...     OPERATIONAL     NaN
# 4  ["establishment", "food", "point_of_interest",...     OPERATIONAL     4.3
#
#    ...  serves_beer  serves_wine dine_in takeout curbside_pickup delivery  \
# 0  ...        False        False    True    True             NaN     True
# 1  ...         True         True    True    True            True     True
# 2  ...         True         True    True    True             NaN    False
# 3  ...          NaN          NaN     NaN     NaN             NaN      NaN
# 4  ...         True         True    True    True           False     True
#
#   reservable                                  editorial_summary  \
# 0      False  Health-conscious cafe serving smoothies & acai...
# 1       True  Modern, low-key sushi house plating artful ren...
# 2       True  Farm-to-table fare from locally sourced ingred...
# 3        NaN                                                NaN
# 4      False  Chicken & waffles highlight the menu at this c...
#
#                                              reviews  \
# 0  [{"rating": 5, "text": "My favorite place to g...
# 1  [{"rating": 4, "text": "The food was surprisin...
# 2  [{"rating": 5, "text": "Amazing food; especial...
# 3                                                 []
# 4  [{"rating": 2, "text": "The tenders, fries and...
#
#                                               photos
# 0  [{"photo_reference": "AciIO2ew_BLTCnbFrsWweBvb...
# 1  [{"photo_reference": "AciIO2egB6RISDznN5oMd7x3...
# 2  [{"photo_reference": "AciIO2fzIWEDXEL7EOYUT8cD...
# 3  [{"photo_reference": "AciIO2dPyDXb_zhnZ-5-4yo7...
# 4  [{"photo_reference": "AciIO2cFtzHjJLhXRXRwjHFI...
#
# [5 rows x 26 columns]

# %%
import json

for i in range(10):
    name = test_df['name'][i]
    types = json.loads(test_df['types'][i])
    print(f"{name}:")
    print(f"  {types}\n")
# Out:
# Blenders & Bowls - Westlake:
#   ['establishment', 'food', 'point_of_interest', 'restaurant']
#
# Tsukimi:
#   ['establishment', 'food', 'point_of_interest', 'restaurant']
#
# Dai Due:
#   ['establishment', 'food', 'point_of_interest', 'restaurant']
#
# El Sazón de mi Ranchito:
#   ['establishment', 'food', 'health', 'point_of_interest', 'restaurant', 'store']
#
# The Rolling Rooster:
#   ['establishment', 'food', 'point_of_interest', 'restaurant']
#
# KFC:
#   ['establishment', 'food', 'point_of_interest', 'restaurant']
#
# Big girl on wheels:
#   ['establishment', 'food', 'point_of_interest', 'restaurant']
#
# 54th Street Restaurant & Drafthouse:
#   ['bar', 'establishment', 'food', 'point_of_interest', 'restaurant']
#
# Besos Cocina & Cantina:
#   ['bar', 'establishment', 'food', 'point_of_interest', 'restaurant']
#
# Twin Lion Chinese Restaurant:
#   ['establishment', 'food', 'meal_takeaway', 'point_of_interest', 'restaurant']

# %%
for i in range(10):
    name = test_df['name'][i]
    summary = test_df['editorial_summary'][i]
    if pd.notna(summary):
        print(f"{name}: {summary}\n")
    else:
        print(f"{name}: No summary\n")
# Out:
# Blenders & Bowls - Westlake: Health-conscious cafe serving smoothies & acai bowls with toppings like fruit & granola.
#
# Tsukimi: Modern, low-key sushi house plating artful renditions of raw seafood & other Japanese fare.
#
# Dai Due: Farm-to-table fare from locally sourced ingredients served in a rustic space with a butcher shop.
#
# El Sazón de mi Ranchito: No summary
#
# The Rolling Rooster: Chicken & waffles highlight the menu at this casual eatery & bar also serving fish & Southern sides.
#
# KFC: Restaurant chain known for its buckets of fried chicken, plus combo meals & sides.
#
# Big girl on wheels: No summary
#
# 54th Street Restaurant & Drafthouse: Chain offering a broad American menu & drinks in a relaxed setting with kitschy, eclectic decor.
#
# Besos Cocina & Cantina: No summary
#
# Twin Lion Chinese Restaurant: A large menu of traditional Chinese dishes, plus some Thai curries, served in a simple dining room.
